# %%
import pandas as pd
import numpy as np

# %%
products=pd.read_csv("/content/drive/MyDrive/capstone/mba/products/products.csv")

# %%
products.head()
# Out:
#    Unnamed: 0  ... product_size_l*b*h_cm3
# 0           0  ...                 2240.0
# 1           1  ...                10800.0
# 2           2  ...                 2430.0
# 3           3  ...                 2704.0
# 4           4  ...                 4420.0
#
# [5 rows x 8 columns]

# %%
products.drop(columns='Unnamed: 0',inplace=True)

# %%
products.head()
# Out:
#                          product_id  ... product_size_l*b*h_cm3
# 0  1e9e8ef04dbcff4541ed26657ea517e5  ...                 2240.0
# 1  3aa071139cb16b67ca9e5dea641aaa2f  ...                10800.0
# 2  96bd76ec8810374ed1b65e291975717f  ...                 2430.0
# 3  cef67bcfe19066a932b7673e239eb23d  ...                 2704.0
# 4  9dc1a7de274444849c219cff195d0b71  ...                 4420.0
#
# [5 rows x 7 columns]

# %%
orders=pd.read_csv('/content/drive/MyDrive/capstone/mba/olist_order_items_dataset.csv')

# %%
orders.head()
# Out:
#                            order_id  order_item_id  ...   price freight_value
# 0  00010242fe8c5a6d1ba2dd792cb16214              1  ...   58.90         13.29
# 1  00018f77f2f0320c557190d7a144bdd3              1  ...  239.90         19.93
# 2  000229ec398224ef6ca0657da4fc703e              1  ...  199.00         17.87
# 3  00024acbcdf0a6daa1e931b038114c75              1  ...   12.99         12.79
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1  ...  199.90         18.14
#
# [5 rows x 7 columns]

# %%
data=pd.merge(orders,products,how='inner',on='product_id')

# %%
data.head()
# Out:
#                            order_id  ...  product_size_l*b*h_cm3
# 0  00010242fe8c5a6d1ba2dd792cb16214  ...                  3528.0
# 1  130898c0987d1801452a8ed92a670612  ...                  3528.0
# 2  532ed5e14e24ae1f0d735b91524b98b9  ...                  3528.0
# 3  6f8c31653edb8c83e1a739408b5ff750  ...                  3528.0
# 4  7d19f4ef4d04461989632411b7e588b9  ...                  3528.0
#
# [5 rows x 13 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112650 entries, 0 to 112649
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   order_id                    112650 non-null  object
#  1   order_item_id               112650 non-null  int64
#  2   product_id                  112650 non-null  object
#  3   seller_id                   112650 non-null  object
#  4   shipping_limit_date         112650 non-null  object
#  5   price                       112650 non-null  float64
#  6   freight_value               112650 non-null  float64
#  7   products_category           112650 non-null  object
#  8   product_name_length         112650 non-null  float64
#  9   product_description_length  111047 non-null  float64
#  10  product_photos_qty          112650 non-null  float64
#  11  product_weight_g            112650 non-null  float64
# ...

# %%
data['order_id'].value_counts() #checking value counts for each order id to make sure there are multiple products in each order id
# Out:
# 8272b63d03f5f79c56e9e4120aec44ef    21
# 1b15974a0141d54e36626dca3fdc731a    20
# ab14fdcfbe524636d65ee38360e22ce8    20
# 9ef13efd6949e4573a18964dd1bbe7f5    15
# 428a2f660dc84138d969ccd69a0ab6d5    15
#                                     ..
# 6958c1e09a9e49c2071dbb679d577422     1
# 7209ee6fd6e98942079c767741b71e3b     1
# 4b8e7be134dcdd11881a5e7de6c88627     1
# 50062ac5439ceb5198b6091b3d7dc288     1
# 1cf390da5ceb2c46855914e5d2520ebc     1
# Name: order_id, Length: 98666, dtype: int64

# %%
data[data['order_id']=='8272b63d03f5f79c56e9e4120aec44ef']
# Out:
#                                order_id  ...  product_size_l*b*h_cm3
# 97511  8272b63d03f5f79c56e9e4120aec44ef  ...                  1260.0
# 97512  8272b63d03f5f79c56e9e4120aec44ef  ...                  1260.0
# 97513  8272b63d03f5f79c56e9e4120aec44ef  ...                  1260.0
# 97514  8272b63d03f5f79c56e9e4120aec44ef  ...                  1260.0
# 97515  8272b63d03f5f79c56e9e4120aec44ef  ...                  1260.0
# 97516  8272b63d03f5f79c56e9e4120aec44ef  ...                  1260.0
# 97517  8272b63d03f5f79c56e9e4120aec44ef  ...                  1260.0
# 97518  8272b63d03f5f79c56e9e4120aec44ef  ...                  1260.0
# 97519  8272b63d03f5f79c56e9e4120aec44ef  ...                  1260.0
# 97520  8272b63d03f5f79c56e9e4120aec44ef  ...                  1260.0
# 97521  8272b63d03f5f79c56e9e4120aec44ef  ...                  1260.0
# 97522  8272b63d03f5f79c56e9e4120aec44ef  ...                  1260.0
# 97523  8272b63d03f5f79c56e9e4120aec44ef  ...                  1260.0
# ...

# %%
data[data['order_id']=='8272b63d03f5f79c56e9e4120aec44ef']['product_id'].value_counts()
# Out:
# 270516a3f41dc035aa87d220228f844c    10
# 05b515fdc76e888aada3c6d66c201dff    10
# 79ce45dbc2ea29b22b5a261bbb7b7ee7     1
# Name: product_id, dtype: int64

# %%
data1=data[['order_id','product_id','products_category']]

# %%
data1.head()
# Out:
#                            order_id  ... products_category
# 0  00010242fe8c5a6d1ba2dd792cb16214  ...            others
# 1  130898c0987d1801452a8ed92a670612  ...            others
# 2  532ed5e14e24ae1f0d735b91524b98b9  ...            others
# 3  6f8c31653edb8c83e1a739408b5ff750  ...            others
# 4  7d19f4ef4d04461989632411b7e588b9  ...            others
#
# [5 rows x 3 columns]

# %%
data1.insert(2, 'quantity',1)
data1.shape
# Out:
# (112650, 4)

# %%
data1.head()
# Out:
#                            order_id  ... products_category
# 0  00010242fe8c5a6d1ba2dd792cb16214  ...            others
# 1  130898c0987d1801452a8ed92a670612  ...            others
# 2  532ed5e14e24ae1f0d735b91524b98b9  ...            others
# 3  6f8c31653edb8c83e1a739408b5ff750  ...            others
# 4  7d19f4ef4d04461989632411b7e588b9  ...            others
#
# [5 rows x 4 columns]

# %%
data1['product_id'].value_counts()
# Out:
# aca2eb7d00ea1a7b8ebd4e68314663af    527
# 99a4788cb24856965c36a24e339b6058    488
# 422879e10f46682990de24d770e7f83d    484
# 389d119b48cf3043d311335e499d9c6b    392
# 368c6c730842d78016ad823897a372db    388
#                                    ...
# f1f0860095cfa6521eb73bd997599888      1
# 6f28dfca954a7cf2b3c3f96aaf059d94      1
# c8648fddfafc439c1c9bb5236945b953      1
# cabdfd59b47b4a3135145f38590da2bd      1
# 60aee8f4bd3599ab0fcd1dcf285c9852      1
# Name: product_id, Length: 32951, dtype: int64

# %%
p1=data1['product_id'].value_counts()

# %%
p1
# Out:
# aca2eb7d00ea1a7b8ebd4e68314663af    527
# 99a4788cb24856965c36a24e339b6058    488
# 422879e10f46682990de24d770e7f83d    484
# 389d119b48cf3043d311335e499d9c6b    392
# 368c6c730842d78016ad823897a372db    388
#                                    ...
# f1f0860095cfa6521eb73bd997599888      1
# 6f28dfca954a7cf2b3c3f96aaf059d94      1
# c8648fddfafc439c1c9bb5236945b953      1
# cabdfd59b47b4a3135145f38590da2bd      1
# 60aee8f4bd3599ab0fcd1dcf285c9852      1
# Name: product_id, Length: 32951, dtype: int64

# %%
p1.index
# Out:
# Index(['aca2eb7d00ea1a7b8ebd4e68314663af', '99a4788cb24856965c36a24e339b6058',
#        '422879e10f46682990de24d770e7f83d', '389d119b48cf3043d311335e499d9c6b',
#        '368c6c730842d78016ad823897a372db', '53759a2ecddad2bb87a079a1f1519f73',
#        'd1c427060a0f73f6b889a5c7c61f2ac4', '53b36df67ebb7c41585e8d54d6772e08',
#        '154e7e31ebfa092203795c972e5804a6', '3dd2a17168ec895c781a9191c1e95ad7',
#        ...
#        '888c70e66e6ead36f2269484a6813212', 'decdbf117444f265f4400886439f5fd7',
#        '08a5cbbd7adc85e1074b03fceaca34ee', '952547036d7de7ce635a81704cd290cd',
#        '059fd0cc43081303f7c0d7770ab53d52', 'f1f0860095cfa6521eb73bd997599888',
#        '6f28dfca954a7cf2b3c3f96aaf059d94', 'c8648fddfafc439c1c9bb5236945b953',
#        'cabdfd59b47b4a3135145f38590da2bd', '60aee8f4bd3599ab0fcd1dcf285c9852'],
#       dtype='object', length=32951)

# %%
p1.values
# Out:
# array([527, 488, 484, ...,   1,   1,   1])

# %%
data1 = data1[data1.isin(p1.index[p1 >= 20]).values]
data1['product_id'].value_counts()
# Out:
# aca2eb7d00ea1a7b8ebd4e68314663af    527
# 99a4788cb24856965c36a24e339b6058    488
# 422879e10f46682990de24d770e7f83d    484
# 389d119b48cf3043d311335e499d9c6b    392
# 368c6c730842d78016ad823897a372db    388
#                                    ...
# 3c883b9d3fd2d0ce448d4136349dc0a4     20
# cf78006a2a6b0429b9663edd99bb38f9     20
# 5f42d57952b7815098979a5c4fa6f82a     20
# 3f1a741cf5591384428c1cbb0ef07ec0     20
# 34dabb8af33b3756cf72df05fb327011     20
# Name: product_id, Length: 709, dtype: int64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34240 entries, 42 to 103577
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_id           34240 non-null  object
#  1   product_id         34240 non-null  object
#  2   quantity           34240 non-null  int64
#  3   products_category  34240 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.3+ MB

# %%
data1.describe(include= 'all')
# Out:
#                                 order_id  ...      products_category
# count                              34240  ...                  34240
# unique                             30420  ...                     11
# top     ab14fdcfbe524636d65ee38360e22ce8  ...  home,office,furniture
# freq                                  20  ...                   8453
# mean                                 NaN  ...                    NaN
# std                                  NaN  ...                    NaN
# min                                  NaN  ...                    NaN
# 25%                                  NaN  ...                    NaN
# 50%                                  NaN  ...                    NaN
# 75%                                  NaN  ...                    NaN
# max                                  NaN  ...                    NaN
#
# [11 rows x 4 columns]

# %%
#Average products purchased per transaction
data1['order_id'].value_counts().mean()
# Out:
# 1.1255752794214333

# %%
data1['order_id'].value_counts()
# Out:
# ab14fdcfbe524636d65ee38360e22ce8    20
# 1b15974a0141d54e36626dca3fdc731a    20
# 428a2f660dc84138d969ccd69a0ab6d5    15
# 73c8ab38f07dc94389065f7eba4f297a    14
# 37ee401157a3a0b28c9c6d0ed8c3b24b    13
#                                     ..
# 36887f26ba41322fdfc422db106a7b05     1
# 5abfc2c21926dd42e4e2a94abd87e23e     1
# f18481fd839eabadc3d84dc73eead362     1
# 346fa124d404d88a793438c41f21932b     1
# 1cf390da5ceb2c46855914e5d2520ebc     1
# Name: order_id, Length: 30420, dtype: int64

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# %%
#Create a basket of all products, orders and quantity
bucket = (data1.groupby(['order_id','product_id'])['quantity']).sum().unstack().reset_index().fillna(0).set_index('order_id')
bucket.head()
# Out:
# product_id                        008cff0e5792219fae03e570f980b330  ...  ffc9caf33e2d1e9f44e3e06da19085f7
# order_id                                                            ...
# 00061f2a7bc09da83e415a52dc8a4af1                               0.0  ...                               0.0
# 0006ec9db01a64e59a68b2c340bf65a7                               0.0  ...                               0.0
# 0008288aa423d2a3f00fcb17cd7d8719                               0.0  ...                               0.0
# 000aed2e25dbad2f9ddb70584c5a2ded                               0.0  ...                               0.0
# 000e562887b1f2006d75e0be9558292e                               0.0  ...                               0.0
#
# [5 rows x 709 columns]

# %%
bucket.describe()
# Out:
# product_id  008cff0e5792219fae03e570f980b330  ...  ffc9caf33e2d1e9f44e3e06da19085f7
# count                           30420.000000  ...                      30420.000000
# mean                                0.000723  ...                          0.000888
# std                                 0.029227  ...                          0.030864
# min                                 0.000000  ...                          0.000000
# 25%                                 0.000000  ...                          0.000000
# 50%                                 0.000000  ...                          0.000000
# 75%                                 0.000000  ...                          0.000000
# max                                 2.000000  ...                          2.000000
#
# [8 rows x 709 columns]

# %%
bucket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30420 entries, 00061f2a7bc09da83e415a52dc8a4af1 to fffc94f6ce00a00581880bf54a75a037
# Columns: 709 entries, 008cff0e5792219fae03e570f980b330 to ffc9caf33e2d1e9f44e3e06da19085f7
# dtypes: float64(709)
# memory usage: 164.8+ MB

# %%
#Convert 0.0 to 0, convert the units to One hot encoded values
def zero_one(x):
    if x<= 0:
        return 0
    if x>=1:
        return 1
    
bucket_sets = bucket.applymap(zero_one)
bucket_sets.head()
# Out:
# product_id                        008cff0e5792219fae03e570f980b330  ...  ffc9caf33e2d1e9f44e3e06da19085f7
# order_id                                                            ...
# 00061f2a7bc09da83e415a52dc8a4af1                                 0  ...                                 0
# 0006ec9db01a64e59a68b2c340bf65a7                                 0  ...                                 0
# 0008288aa423d2a3f00fcb17cd7d8719                                 0  ...                                 0
# 000aed2e25dbad2f9ddb70584c5a2ded                                 0  ...                                 0
# 000e562887b1f2006d75e0be9558292e                                 0  ...                                 0
#
# [5 rows x 709 columns]

# %%
bucket_sets1=bucket_sets[(bucket_sets>0).sum(axis=1)>=2] #considering orderids with more than 1 product only to use them in association
bucket_sets1
# Out:
# product_id                        008cff0e5792219fae03e570f980b330  ...  ffc9caf33e2d1e9f44e3e06da19085f7
# order_id                                                            ...
# 012a238ab54294a3b365812ccc82b135                                 0  ...                                 0
# 0132451f29a10b66a5cf1bacc85f9afe                                 0  ...                                 0
# 015183dcb37f19e0456905fa5aac0b69                                 0  ...                                 0
# 033dbd83c331548108afda89d5bc6b79                                 0  ...                                 0
# 034afd1b074e35a1d1dcf70c4a5641b5                                 0  ...                                 0
# ...                                                            ...  ...                               ...
# f930a1f6247ed00d6fa9d8a09782c7b4                                 0  ...                                 0
# ...

# %%
###Frequent Itemsets
#Build frequent itemsets
frequent_itemsets = apriori(bucket_sets1, min_support = 0.001, use_colnames = True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
# Out:
#       support                                           itemsets  length
# 0    0.002457                 (0152f69b6cf919bcdaf117aa8c43e5a2)       1
# 1    0.014742                 (060cb19345d90064d1015407193c233d)       1
# 2    0.007371                 (07c055536ebf10dfbb6c6db6dbfc36e5)       1
# 3    0.002457                 (08574b074924071f4e201e151b152b4e)       1
# 4    0.004914                 (09b0d15a8cc9a84e7af7e0225f67dc45)       1
# ..        ...                                                ...     ...
# 471  0.002457  (42a2bd596fda1baef5719cb74f73030c, 98b22c11298...       3
# 472  0.002457  (fb783e3e545937820b57fe539b2c5a6c, 8a443635fdf...       3
# 473  0.002457  (98ec655119c24de03b804696821f3955, f40876e0ef3...       3
# 474  0.002457  (0bcc3eeca39e1064258aa1e932269894, 389d119b48c...       4
# 475  0.002457  (87d780fa7d2cf3710aa02dc4ca8db985, fb783e3e545...       4
#
# [476 rows x 3 columns]

# %%
association_rules(frequent_itemsets)
# Out:
#                                            antecedents  ... conviction
# 0                   (0152f69b6cf919bcdaf117aa8c43e5a2)  ...        inf
# 1                   (642a40d4d73b4b2604968937de13634a)  ...        inf
# 2                   (060cb19345d90064d1015407193c233d)  ...        inf
# 3                   (98a8c2fa16d7239c606640f5555768e4)  ...        inf
# 4                   (08574b074924071f4e201e151b152b4e)  ...        inf
# ..                                                 ...  ...        ...
# 171  (0fa81e7123fd0ebe03adbbe99d912827, 8a443635fdf...  ...        inf
# 172  (fb783e3e545937820b57fe539b2c5a6c, 8a443635fdf...  ...        inf
# 173  (fb783e3e545937820b57fe539b2c5a6c, 87d780fa7d2...  ...        inf
# 174  (fb783e3e545937820b57fe539b2c5a6c, 8a443635fdf...  ...        inf
# 175  (8a443635fdf9759915c9be5be2e3b862, 0fa81e7123f...  ...        inf
#
# [176 rows x 9 columns]
